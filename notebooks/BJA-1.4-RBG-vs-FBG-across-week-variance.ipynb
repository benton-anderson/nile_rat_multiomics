# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dateutil

# %%
# Import data

fr_raw = pd.read_csv(r'..\data\search\peak_finder\Final_Results.csv').dropna(axis=1, how='all')
fr_filt = pd.read_csv(r'..\data\processed\filtered_raw_data.csv', index_col=0)
fr_norm = pd.read_csv(r'..\data\processed\run_1_median_linregress_normalized_data.csv', index_col=0)
file_grouping = pd.read_csv(r'..\data\metadata\file_groupings.csv')

fr_quant_filenames_in_analytical_order = file_grouping[file_grouping['quant_file'] == True]['fr_name'].to_list()

animals_used = [1091, 1093, 1060, 1062, 1074, 1092, 1102, 1076, 1082, 1101]

diabetic = [1076, 1082, 1101]
impaired = [1060, 1062, 1074, 1092, 1102]
normal = [1091, 1093]

obs = pd.read_excel(r'..\data\metadata\20210421_FBGRBGOGTT_Huishi sample sheet.xlsx', sheet_name='cleaned')
obs['animal'] = obs['animal'].str.strip('TM').astype('int')
obs['datetime'] = obs['when'].apply(dateutil.parser.parse)
animal_phenotypes = pd.read_excel(r'..\data\metadata\20210421_FBGRBGOGTT_Huishi sample sheet.xlsx', sheet_name='animal phenotypes')
animal_phenotypes['animal'] = animal_phenotypes['animal'].str.strip('TM').astype('int')

# %%
fr_norm.head(1)
# Out:
#          Unique Identifier  Retention Time (min)  Quant Ion Polarity  \
# 0  unknown_679.05463_0.536                 0.536  679.05463        +
#
#     Area (max) Identification Lipid Class  Features Found  \
# 0  24084205.57        unknown     unknown              49
#
#    20210729_AJ_Toh_RatBloodGlucose_T1060M_20210322_8wk_FBG.raw (F3)  \
# 0                                       9.961276e+06
#
#    20210729_AJ_Toh_RatBloodGlucose_T1060M_20210325_8wk_RBG.raw (F4)  ...  \
# 0                                       1.691781e+07                 ...
#
#    20210729_AJ_Toh_RatBloodGlucose_T1101M_20210402_9wk_FBG.raw (F55)  \
# 0                                       1.156171e+07
#
#    20210729_AJ_Toh_RatBloodGlucose_T1101M_20210406_9wk_RBG.raw (F56)  \
# 0                                       9.016913e+06
#
#    20210729_AJ_Toh_RatBloodGlucose_T1101M_20210410_10wk_FBG.raw (F57)  \
# 0                                       5.355228e+06
#
#    20210729_AJ_Toh_RatBloodGlucose_T1101M_20210413_10wk_RBG.raw (F58)  \
# 0                                       1.613667e+07
#
#    20210729_AJ_Toh_RatBloodGlucose_T1102M_20210327_8wk_FBG.raw (F59)  \
# 0                                       1.206792e+07
#
#    20210729_AJ_Toh_RatBloodGlucose_T1102M_20210330_8wk_RBG.raw (F60)  \
# 0                                       1.076659e+07
#
#    20210729_AJ_Toh_RatBloodGlucose_T1102M_20210402_9wk_FBG.raw (F61)  \
# 0                                       1.182398e+07
#
#    20210729_AJ_Toh_RatBloodGlucose_T1102M_20210406_9wk_RBG.raw (F62)  \
# 0                                       9.694285e+06
#
#    20210729_AJ_Toh_RatBloodGlucose_T1102M_20210410_10wk_FBG.raw (F63)  \
# 0                                       9.361182e+06
#
#    20210729_AJ_Toh_RatBloodGlucose_T1102M_20210413_10wk_RBG.raw (F64)
# 0                                       1.109741e+07
#
# [1 rows x 68 columns]

# %%
file_grouping
# Out:
#                                             File Name  analytical_run_order  \
# 0            20210729_AJ_Toh_RatBloodGlucose_Water_R1                     1
# 1            20210729_AJ_Toh_RatBloodGlucose_Water_R2                     2
# 2            20210729_AJ_Toh_RatBloodGlucose_Water_R3                     3
# 3        20210729_AJ_Toh_RatBloodGlucose_SolventBlank                     4
# 4     20210729_AJ_Toh_RatBloodGlucose_ExtractionBlank                     5
# ..                                                ...                   ...
# 62  20210729_AJ_Toh_RatBloodGlucose_T1062M_2021040...                    63
# 63  20210729_AJ_Toh_RatBloodGlucose_T1101M_2021033...                    64
# 64  20210729_AJ_Toh_RatBloodGlucose_T1092M_2021033...                    65
# 65  20210729_AJ_Toh_RatBloodGlucose_T1092M_2021041...                    66
# 66  20210729_AJ_Toh_RatBloodGlucose_T1062M_2021032...                    67
#
#                                               fr_name  rat_label bg_type  \
# 0   20210729_AJ_Toh_RatBloodGlucose_Water_R1.raw (...        NaN     NaN
# 1   20210729_AJ_Toh_RatBloodGlucose_Water_R2.raw (...        NaN     NaN
# 2   20210729_AJ_Toh_RatBloodGlucose_Water_R3.raw (...        NaN     NaN
# 3   20210729_AJ_Toh_RatBloodGlucose_SolventBlank.r...        NaN     NaN
# 4   20210729_AJ_Toh_RatBloodGlucose_ExtractionBlan...        NaN     NaN
# ..                                                ...        ...     ...
# 62  20210729_AJ_Toh_RatBloodGlucose_T1062M_2021040...     1062.0     RBG
# 63  20210729_AJ_Toh_RatBloodGlucose_T1101M_2021033...     1101.0     RBG
# 64  20210729_AJ_Toh_RatBloodGlucose_T1092M_2021033...     1092.0     RBG
# 65  20210729_AJ_Toh_RatBloodGlucose_T1092M_2021041...     1092.0     RBG
# 66  20210729_AJ_Toh_RatBloodGlucose_T1062M_2021032...     1062.0     FBG
#
#     quant_file  week  lipidex_file_number        date glucose_tolerance
# 0        False   NaN                   65         NaN               NaN
# 1        False   NaN                   66         NaN               NaN
# 2        False   NaN                   67         NaN               NaN
# 3        False   NaN                    2         NaN               NaN
# 4        False   NaN                    1         NaN               NaN
# ..         ...   ...                  ...         ...               ...
# 62        True   9.0                   14  2021-04-01          impaired
# 63        True   8.0                   54  2021-03-30          diabetic
# 64        True   8.0                   42  2021-03-30          impaired
# 65        True  10.0                   46  2021-04-13          impaired
# 66       False   9.0                   13         NaN          impaired
#
# [67 rows x 10 columns]

# %% [markdown]
# For each feature:
# 1. Get columns corresponding to each animal, regardless of week
# 2. Within those columns, separate by RBG vs FBG
# 3. Take RSD of RBG from all 3 weeks
# 4. Write that RSD to new DF with column name as "Animal#_RBG/FBG"

# %%
fr_norm[fr_quant_filenames_in_analytical_order][cols]
# Out:
#       20210729_AJ_Toh_RatBloodGlucose_T1102M_20210402_9wk_FBG.raw (F61)  \
# 0                                          1.182398e+07
# 1                                          3.171840e+07
# 2                                          1.528755e+07
# 3                                          1.275793e+08
# 4                                          8.584741e+06
# ...                                                 ...
# 1481                                       2.456722e+05
# 1482                                       6.770359e+05
# 1483                                       3.906703e+05
# 1484                                       1.552571e+05
# 1486                                       1.049134e+05
#
#       20210729_AJ_Toh_RatBloodGlucose_T1102M_20210327_8wk_FBG.raw (F59)  \
# 0                                          1.206792e+07
# 1                                          3.004373e+07
# 2                                          1.397276e+07
# 3                                          8.073146e+07
# 4                                          5.958120e+06
# ...                                                 ...
# 1481                                       3.020530e+05
# 1482                                       9.924767e+05
# 1483                                       6.600295e+05
# 1484                                       3.057656e+05
# 1486                                       1.938229e+05
#
#       20210729_AJ_Toh_RatBloodGlucose_T1102M_20210410_10wk_FBG.raw (F63)
# 0                                          9.361182e+06
# 1                                          2.183496e+07
# 2                                          1.339975e+07
# 3                                          1.168454e+08
# 4                                          5.852656e+06
# ...                                                 ...
# 1481                                       4.061090e+05
# 1482                                       1.194394e+06
# 1483                                       7.709440e+05
# 1484                                       3.311393e+05
# 1486                                       1.974585e+05
#
# [1136 rows x 3 columns]

# %%
rsd_data_by_animal = pd.DataFrame()

for animal in animals_used:
    for bg_type in ['RBG', 'FBG']:
        # subset file_grouping to avoid looking into QC1 and QC3 files
        grouping = file_grouping.drop(file_grouping[file_grouping['fr_name'].isin(fr_nonquant_filenames)].index)
        
        cols = grouping[(grouping['bg_type'] == bg_type) & (grouping['rat_label'] == animal)]['fr_name']
        
        fr_norm_subset = fr_norm[fr_quant_filenames_in_analytical_order]
        rsd_data_by_animal[str(animal) + '_' + bg_type] = \
            fr_norm_subset[cols].std(axis=1) / (fr_norm_subset[cols].mean(axis=1))
        
rsd_data_by_animal
# Out:
#       1091_RBG  1091_FBG  1060_RBG  1060_FBG  1092_RBG  1092_FBG  1062_RBG  \
# 0     0.222652  0.411256  0.424170  0.118236  0.104275  0.342164  0.434835
# 1     0.429315  0.662362  0.428418  0.360134  0.126427  0.125761  0.847836
# 2     0.654049  0.262721  0.577476  0.284134  0.245879  0.326268  0.271214
# 3     0.019071  0.232021  0.490215  0.178983  0.287777  0.463710  0.192200
# 4     0.570087  0.463047  0.576236  0.273049  0.564445  0.311069  0.321922
# ...        ...       ...       ...       ...       ...       ...       ...
# 1481  0.630073  0.803179  0.249185  0.479409  0.261021  0.587450  0.156021
# 1482  0.441444  0.301905  0.237096  0.334083  0.247056  0.493579  0.460994
# 1483  0.514968  0.452213  0.399023  0.318662  0.629283  0.525930  0.342437
# 1484  0.890759  1.060310  0.240417  0.627215  0.131208  0.605692  0.456907
# 1486  0.917738  0.872831  0.147119  0.849237  0.243348  0.672973  0.412103
#
#       1062_FBG  1093_RBG  1093_FBG  1101_RBG  1101_FBG  1102_RBG  1102_FBG  \
# 0     0.102265  0.456348  0.233246  0.288176  0.409295  0.069727  0.135082
# 1     0.112327  0.423827  0.149696  0.221037  0.223800  0.648786  0.189820
# 2     0.251867  0.208166  0.216775  0.133764  0.200914  0.204017  0.068065
# 3     0.157578  0.413777  0.180631  0.388635  0.177441  0.185410  0.226442
# 4     0.132426  0.366394  0.440719  0.105851  0.257512  0.384827  0.227671
# ...        ...       ...       ...       ...       ...       ...       ...
# 1481  0.504118  0.583442  0.607246  0.566018  0.516952  0.324510  0.255989
# 1482  0.210517  0.376696  0.403373  0.222721  0.477984  0.556882  0.273138
# 1483  0.118001  0.382808  0.449174  0.345819  0.432107  0.447668  0.322062
# 1484  0.661903  0.296881  0.467142  0.772535  0.707078  0.322410  0.360045
# 1486  0.920663  0.758673  0.521146  0.676286  1.015901  0.307519  0.316890
#
#       1074_RBG  1074_FBG  1076_RBG  1076_FBG  1082_RBG  1082_FBG
# 0     0.132207  0.453755  0.248870  0.799734  0.127956  0.109677
# 1     0.227550  0.705987  0.352582  1.052718  0.393197  0.080920
# 2     0.359187  0.262542  0.199728  0.776080  0.527450  0.063245
# 3     0.084069  0.287536  0.306956  0.732511  0.427381  0.224225
# 4     0.135805  0.112507  0.155312  0.770999  0.428606  0.344655
# ...        ...       ...       ...       ...       ...       ...
# 1481  0.077109  0.397566  0.478767  0.712987  0.800758  1.130374
# 1482  0.431171  0.581360  0.139100  0.684931  0.398690  0.696999
# 1483  0.582490  0.864828  0.111545  0.423573  0.272331  0.690609
# 1484  0.194593  0.677755  0.291311  0.603952  0.417892  1.152518
# 1486  0.167428  0.888575  0.198450  0.824891  0.553321  0.992641
#
# [1136 rows x 20 columns]

# %% [markdown]
# ### Compare the

# %%
df = rsd_data_by_animal

fig, axs = plt.subplots(nrows=10, ncols=1, constrained_layout=True)
fig.set_size_inches((10, 40))
# plt.tight_layout()

for i, animal in enumerate(animals_used):  # i = row index for axs

        subdf = df.filter(regex=str(animal))
        
        gluc_tol = animal_phenotypes[animal_phenotypes['animal'] == animal]['glucose_tolerance'].values[0]

        ax = axs[i]
        
        ax.hist(subdf.iloc[:, 0], alpha=0.5, label='RBG', bins=25)  # 0th column is RBG
        ax.hist(subdf.iloc[:, 1], alpha=0.5, label='FBG', bins=25)  # 1st column is FBG
        
        ax.grid(alpha=0.5, axis='y')

        ax.set_title(f'animal: {animal}\nglucose tolerance = {gluc_tol}')

handles, labels = plt.gca().get_legend_handles_labels()

fig.legend(handles[:2], labels[:2], )
        
# fig.suptitle('Lipid Class and Glucose Tolerance\nRBG vs FBG\nAverage of all 3 weeks', fontsize=20)

# %% [markdown]
# ### What if we compare RSDs of all random samples vs all fasted samples?

# %%
rsd_data_all = pd.DataFrame()

for bg_type in ['RBG', 'FBG']:
    # subset file_grouping to avoid looking into QC1 and QC3 files
    grouping = file_grouping.drop(file_grouping[file_grouping['fr_name'].isin(fr_nonquant_filenames)].index)

    cols = grouping[(grouping['bg_type'] == bg_type)]['fr_name']

    fr_norm_subset = fr_norm[fr_quant_filenames_in_analytical_order]
    rsd_data_all[bg_type] = \
        fr_norm_subset[cols].std(axis=1) / (fr_norm_subset[cols].mean(axis=1))
        
rsd_data_all
# Out:
#            RBG       FBG
# 0     0.289434  0.333655
# 1     0.415117  0.392395
# 2     0.370802  0.313391
# 3     0.276045  0.285436
# 4     0.376937  0.342978
# ...        ...       ...
# 1481  1.195558  0.686966
# 1482  0.846742  0.590667
# 1483  0.764400  0.672877
# 1484  1.043145  0.748321
# 1486  1.083408  0.869888
#
# [1136 rows x 2 columns]

# %%
plt.hist(rsd_data_all['RBG'], alpha=0.5, bins=60)
plt.hist(rsd_data_all['FBG'], alpha=0.5, bins=60)
# plt.xlim(0,2)
# plt.ylim(0, 20)
fig = plt.gcf()
# fig.figsize = (20,20)
plt.legend(['RBG', 'FBG'])

# %% [markdown]
# ### The blue distribution (RBG) of all rat samples has a distinct 2nd hump as if it's bimodal
#
# ### if we exclude diabetic rats from this calculation, does the 2nd hump go away?

# %%
rsd_data_by_gluc_tol = pd.DataFrame()

gluc_tolerances = ['normal', 'impaired', 'diabetic']

for gluc_tol in gluc_tolerances:
    for bg_type in ['RBG', 'FBG']:

        # subset file_grouping to avoid looking into QC1 and QC3 files
        grouping = file_grouping.drop(file_grouping[file_grouping['fr_name'].isin(fr_nonquant_filenames)].index)

        cols = grouping[(grouping['glucose_tolerance'] == gluc_tol) & (grouping['bg_type'] == bg_type)]['fr_name']

        fr_norm_subset = fr_norm[fr_quant_filenames_in_analytical_order]
        rsd_data_by_gluc_tol[f'{gluc_tol}_{bg_type}'] = \
            fr_norm_subset[cols].std(axis=1) / (fr_norm_subset[cols].mean(axis=1))
        
rsd_data_by_gluc_tol
# Out:
#       normal_RBG  normal_FBG  impaired_RBG  impaired_FBG  diabetic_RBG  \
# 0       0.319508    0.349436      0.309231      0.232264      0.222281
# 1       0.408032    0.447442      0.477949      0.346735      0.293812
# 2       0.417098    0.280873      0.375754      0.249416      0.367311
# 3       0.259046    0.204729      0.248239      0.274908      0.344361
# 4       0.424338    0.426676      0.428409      0.267417      0.284269
# ...          ...         ...           ...           ...           ...
# 1481    0.557582    0.805299      0.413996      0.444141      0.895190
# 1482    0.393335    0.634359      0.510130      0.429429      0.585074
# 1483    0.409646    0.689014      0.490385      0.511233      0.451337
# 1484    0.550728    0.682744      0.551133      0.680679      0.720470
# 1486    0.749785    0.631403      0.477820      0.811039      0.726414
#
#       diabetic_FBG
# 0         0.446985
# 1         0.473649
# 2         0.394498
# 3         0.374347
# 4         0.431320
# ...            ...
# 1481      0.859524
# 1482      0.590182
# 1483      0.502821
# 1484      0.802641
# 1486      1.074188
#
# [1136 rows x 6 columns]

# %%
df = rsd_data_by_gluc_tol

fig, axs = plt.subplots(nrows=3, ncols=1, constrained_layout=True)
fig.set_size_inches((10, 20))
# plt.tight_layout()

for i, gluc_tol in enumerate(gluc_tolerances):  # i = row index for axs

        subdf = df.filter(regex=str(gluc_tol))
        
        ax = axs[i]
        
        ax.hist(subdf.iloc[:, 0], alpha=0.5, label='RBG', bins=33)  # 0th column is RBG
        ax.hist(subdf.iloc[:, 1], alpha=0.5, label='FBG', bins=33)  # 1st column is FBG
        
        ax.grid(alpha=0.5, axis='y')

        ax.set_title(f'glucose tolerance = {gluc_tol}')

handles, labels = plt.gca().get_legend_handles_labels()

fig.legend(handles[:2], labels[:2], )
        
# fig.suptitle('Lipid Class and Glucose Tolerance\nRBG vs FBG\nAverage of all 3 weeks', fontsize=20)

# %%
cols = file_grouping[(file_grouping['bg_type'] == 'FBG') & (file_grouping['rat_label'] == 1102)]['fr_name']

fr_norm[cols].median(axis=1)
# Out:
# 0       1.182398e+07
# 1       3.004373e+07
# 2       1.397276e+07
# 3       1.168454e+08
# 4       5.958120e+06
#             ...
# 1481    3.020530e+05
# 1482    9.924767e+05
# 1483    6.600295e+05
# 1484    3.057656e+05
# 1486    1.938229e+05
# Length: 1136, dtype: float64

# %%
fr_nonquant_filenames
# Out:
# Index(['20210729_AJ_Toh_RatBloodGlucose_ExtractionBlank.raw (F1)',
#        '20210729_AJ_Toh_RatBloodGlucose_SolventBlank.raw (F2)',
#        '20210729_AJ_Toh_RatBloodGlucose_T1062M_20210329_9wk_FBG_QC1.raw (F11)',
#        '20210729_AJ_Toh_RatBloodGlucose_T1062M_20210329_9wk_FBG_QC3.raw (F13)',
#        '20210729_AJ_Toh_RatBloodGlucose_Water_R1.raw (F65)',
#        '20210729_AJ_Toh_RatBloodGlucose_Water_R2.raw (F66)',
#        '20210729_AJ_Toh_RatBloodGlucose_Water_R3.raw (F67)'],
#       dtype='object')

# %%
file_grouping.drop(file_grouping['fr_name'].isin(fr_nonquant_filenames).index)
# Out:
# Empty DataFrame
# Columns: [File Name, analytical_run_order, fr_name, rat_label, bg_type, quant_file, week, lipidex_file_number, date, glucose_tolerance]
# Index: []

# %%
file_grouping
# Out:
#                                             File Name  analytical_run_order  \
# 0            20210729_AJ_Toh_RatBloodGlucose_Water_R1                     1
# 1            20210729_AJ_Toh_RatBloodGlucose_Water_R2                     2
# 2            20210729_AJ_Toh_RatBloodGlucose_Water_R3                     3
# 3        20210729_AJ_Toh_RatBloodGlucose_SolventBlank                     4
# 4     20210729_AJ_Toh_RatBloodGlucose_ExtractionBlank                     5
# ..                                                ...                   ...
# 62  20210729_AJ_Toh_RatBloodGlucose_T1062M_2021040...                    63
# 63  20210729_AJ_Toh_RatBloodGlucose_T1101M_2021033...                    64
# 64  20210729_AJ_Toh_RatBloodGlucose_T1092M_2021033...                    65
# 65  20210729_AJ_Toh_RatBloodGlucose_T1092M_2021041...                    66
# 66  20210729_AJ_Toh_RatBloodGlucose_T1062M_2021032...                    67
#
#                                               fr_name  rat_label bg_type  \
# 0   20210729_AJ_Toh_RatBloodGlucose_Water_R1.raw (...        NaN     NaN
# 1   20210729_AJ_Toh_RatBloodGlucose_Water_R2.raw (...        NaN     NaN
# 2   20210729_AJ_Toh_RatBloodGlucose_Water_R3.raw (...        NaN     NaN
# 3   20210729_AJ_Toh_RatBloodGlucose_SolventBlank.r...        NaN     NaN
# 4   20210729_AJ_Toh_RatBloodGlucose_ExtractionBlan...        NaN     NaN
# ..                                                ...        ...     ...
# 62  20210729_AJ_Toh_RatBloodGlucose_T1062M_2021040...     1062.0     RBG
# 63  20210729_AJ_Toh_RatBloodGlucose_T1101M_2021033...     1101.0     RBG
# 64  20210729_AJ_Toh_RatBloodGlucose_T1092M_2021033...     1092.0     RBG
# 65  20210729_AJ_Toh_RatBloodGlucose_T1092M_2021041...     1092.0     RBG
# 66  20210729_AJ_Toh_RatBloodGlucose_T1062M_2021032...     1062.0     FBG
#
#     quant_file  week  lipidex_file_number        date glucose_tolerance
# 0        False   NaN                   65         NaN               NaN
# 1        False   NaN                   66         NaN               NaN
# 2        False   NaN                   67         NaN               NaN
# 3        False   NaN                    2         NaN               NaN
# 4        False   NaN                    1         NaN               NaN
# ..         ...   ...                  ...         ...               ...
# 62        True   9.0                   14  2021-04-01          impaired
# 63        True   8.0                   54  2021-03-30          diabetic
# 64        True   8.0                   42  2021-03-30          impaired
# 65        True  10.0                   46  2021-04-13          impaired
# 66       False   9.0                   13         NaN          impaired
#
# [67 rows x 10 columns]

# %%
# Out:
#                                             File Name  analytical_run_order  \
# 6   20210729_AJ_Toh_RatBloodGlucose_T1076M_2021040...                     7
# 7   20210729_AJ_Toh_RatBloodGlucose_T1062M_2021032...                     8
# 8   20210729_AJ_Toh_RatBloodGlucose_T1093M_2021040...                     9
# 9   20210729_AJ_Toh_RatBloodGlucose_T1060M_2021032...                    10
# 10  20210729_AJ_Toh_RatBloodGlucose_T1091M_2021041...                    11
# 11  20210729_AJ_Toh_RatBloodGlucose_T1092M_2
20210729_AJ_Toh_RatBloodGlucose_T1092M_2021033...     1092.0     RBG
# 65  20210729_AJ_Toh_RatBloodGlucose_T1092M_2021041...     1092.0     RBG
#
#     quant_file  week  lipidex_file_number        date glucose_tolerance
# 6         True  10.0                   27  2021-04-05          diabetic
# 7         True   8.0                    9  2021-03-22          impaired
# 8         True   9.0                   49  2021-04-02            normal
# 9         True   8.0                    4  2021-03-25          impaired
# 10        True  10.0                   39  2021-04-10            normal
# 11        True   9.0                   44  2021-04-06          impaired
# 12        True  10.0                   52  2021-04-13            normal
# 13        True  10.0                   33  2021-04-05          diabetic
# 14        True   9.0                    6  2021-04-01          impaired
# 15        True   9.0                   55  2021-04-02          diabetic
# 16        True  10.0                   16  2021-04-08          impaired
# 17        True   8.0                   36  2021-03-30            normal
# 18        True  10.0                   21  2021-04-05          impaired
# 19        True  10.0                   58  2021-04-13          diabetic
# 20        True   9.0                   25  2021-03-29          diabetic
# 21        True   9.0                   43  2021-04-02          impaired
# 22        True   8.0                   17  2021-03-22          impaired
# 23        True  10.0                   40  2021-04-13            normal
# 24        True   9.0                   31  2021-03-29          diabetic
# 25        True   8.0                   24  2021-03-25          diabetic
# 26        True   8.0                    3  2021-03-22          impaired
# 27        True   9.0                   50  2021-04-06            normal
# 28        True  10.0                    7  2021-04-05          impaired
# 29        True  10.0                   34  2021-04-08          diabetic
# 30        True   9.0                   20  2021-04-01          impaired
# 31        True   9.0                   38  2021-04-06            normal
# 32        True  10.0                   57  2021-04-10          diabetic
# 33        True   8.0                   47  2021-03-27            normal
# 34        True   8.0                   18  2021-03-25          impaired
# 35        True  10.0                   64  2021-04-13          impaired
# 36        True   9.0                   12  2021-03-29          impaired
# 37        True   9.0                   26  2021-04-01          diabetic
# 38        True   8.0                   41  2021-03-27          impaired
# 39        True  10.0                   15  2021-04-05          impaired
# 40        True   8.0                   60  2021-03-30          impaired
# 41        True  10.0                   22  2021-04-08          impaired
# 42        True   9.0                    5  2021-03-29          impaired
# 43        True   9.0                   32  2021-04-01          diabetic
# 44        True  10.0                   28  2021-04-08          diabetic
# 45        True   9.0                   37  2021-04-02            normal
# 46        True   9.0                   61  2021-04-02          impaired
# 47        True   9.0                   62  2021-04-06          impaired
# 48        True  10.0                   51  2021-04-10            normal
# 49        True   8.0                   53  2021-03-27          diabetic
# 50        True   8.0                   59  2021-03-27          impaired
# 51        True   8.0                   29  2021-03-22          diabetic
# 52        True  10.0                    8  2021-04-08          impaired
# 53        True   8.0                   23  2021-03-22          diabetic
# 54        True   9.0                   56  2021-04-06          diabetic
# 55        True   8.0                   35  2021-03-27            normal
# 56        True  10.0                   45  2021-04-10          impaired
# 57        True   8.0                   30  2021-03-25          diabetic
# 58        True   8.0                   10  2021-03-25          impaired
# 59        True  10.0                   63  2021-04-10          impaired
# 60        True   8.0                   48  2021-03-30            normal
# 61        True   9.0                   19  2021-03-29          impaired
# 62        True   9.0                   14  2021-04-01          impaired
# 63        True   8.0                   54  2021-03-30          diabetic
# 64        True   8.0                   42  2021-03-30          impaired
# 65        True  10.0                   46  2021-04-13          impaired
