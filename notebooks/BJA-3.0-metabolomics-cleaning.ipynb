# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dateutil

# %%
animals_used = [1091, 1093, 1060, 1062, 1074, 1092, 1102, 1076, 1082, 1101]
diabetic = [1076, 1082, 1101]
impaired = [1060, 1062, 1074, 1092, 1102]
normal = [1091, 1093]
bg_dict = {'diabetic': diabetic, 'impaired': impaired, 'normal': normal}
animal_to_tolerance_dict = {1076: 'diabetic', 1082: 'diabetic',1101: 'diabetic',
                            1060: 'impaired', 1062: 'impaired', 1074: 'impaired', 1092: 'impaired', 1102: 'impaired', 
                            1091: 'normal', 1093: 'normal',}

obs = pd.read_excel(r'..\data\metadata\20210421_FBGRBGOGTT_Huishi sample sheet.xlsx', sheet_name='cleaned')
obs['animal'] = obs['animal'].str.strip('TM').astype('int')
obs['datetime'] = obs['when'].apply(dateutil.parser.parse)
animal_phenotypes = pd.read_excel(r'..\data\metadata\20210421_FBGRBGOGTT_Huishi sample sheet.xlsx', sheet_name='animal phenotypes')
animal_phenotypes['animal'] = animal_phenotypes['animal'].str.strip('TM').astype('int')

metab_file_grouping = pd.read_csv(r'..\data\metadata\20210831_KAO_HILIC_Huishi_sequence.csv',
                               skiprows=1)
metab_file_grouping['analytical_order'] = list(range(0,69))
metab_file_grouping = metab_file_grouping[['File Name', 'analytical_order']]

bad_file = '20210831_KAO_HILIC_ACN'  # file size is only 800 kB and it failed to convert in MSConvert
typo_files = {'20210831_KAO_HILIC_T193M20210406_9wk_RBG': '20210831_KAO_HILIC_T1093M_20210406_9wk_RBG',
              '20210831_KAO_HILIC_T1092_20210410_10wk_FBG': '20210831_KAO_HILIC_T1092M_20210410_10wk_FBG',
              '20210831_KAO_HILIC_T112M_20210330_8wk_RBG': '20210831_KAO_HILIC_T1102M_20210330_8wk_RBG',
              '20210831_KAO_HILIC_T1092M_20210402_wk_FBG': '20210831_KAO_HILIC_T1092M_20210402_9wk_FBG'}
qc_files = list(metab_file_grouping[metab_file_grouping['File Name'].str.contains('human')]['File Name'].values)
blank_files = ['20210831_KAO_HILIC_ACN', '20210831_KAO_HILIC_ACN_20210831232610',
               '20210831_KAO_HILIC_extraction_blank_1', '20210831_KAO_HILIC_extraction_blank_1_20210901004002']

def fix_filename(original_filename):
    if original_filename in typo_files:
        return typo_files[original_filename]
    else:
        return original_filename

metab_file_grouping['fixed_filename'] = metab_file_grouping['File Name'].apply(fix_filename)

metab_file_grouping['qc_file'] = metab_file_grouping['File Name'].isin(qc_files)
metab_file_grouping['quant_file'] = metab_file_grouping['fixed_filename'].str.contains('HILIC_T')
metab_file_grouping['blank_file'] = metab_file_grouping['File Name'].isin(blank_files)
metab_file_grouping = metab_file_grouping.drop(0)  # File is 800 kB and doesn't open

metab_file_grouping['animal'] = metab_file_grouping['fixed_filename'].str.split('HILIC_T').str[1].str.split('M_2021').str[0]
metab_file_grouping['week'] = metab_file_grouping[metab_file_grouping['quant_file'] == True]\
                                 ['fixed_filename'].str.split('wk_').str[0].str.split('_').str[-1]
metab_file_grouping['bg_type'] = metab_file_grouping[metab_file_grouping['quant_file'] == True]\
                                   ['fixed_filename'].str.split('_').str[-1]
metab_file_grouping['glucose_tolerance'] = metab_file_grouping['animal'].astype('float').astype('Int64').map(animal_to_tolerance_dict)

metab_file_grouping.to_csv(r'..\data\metadata\metabolomics_file_grouping.csv', index=False)

# %%
metab_file_grouping = pd.read_csv(r'..\data\metadata\metabolomics_file_grouping.csv')
metab_file_grouping
# Out:
#                                             File Name  analytical_order  \
# 0               20210831_KAO_HILIC_ACN_20210831232610                 1
# 1               20210831_KAO_HILIC_extraction_blank_1                 2
# 2   20210831_KAO_HILIC_extraction_blank_1_20210901...                 3
# 3                   20210831_KAO_HILIC_human_plasma_1                 4
# 4          20210831_KAO_HILIC_T1060M_20210401_9wk_RBG                 5
# ..                                                ...               ...
# 63        20210831_KAO_HILIC_T1060M_20210408_10wk_RBG                64
# 64         20210831_KAO_HILIC_T1102M_20210327_8wk_FBG                65
# 65         20210831_KAO_HILIC_T1074M_20210322_8wk_FBG                66
# 66         20210831_KAO_HILIC_T1082M_20210401_9wk_RBG                67
# 67                  20210831_KAO_HILIC_human_plasma_5                68
#
#                                        fixed_filename  qc_file  quant_file  \
# 0               20210831_KAO_HILIC_ACN_20210831232610    False       False
# 1               20210831_KAO_HILIC_extraction_blank_1    False       False
# 2   20210831_KAO_HILIC_extraction_blank_1_20210901...    False       False
# 3                   20210831_KAO_HILIC_human_plasma_1     True       False
# 4          20210831_KAO_HILIC_T1060M_20210401_9wk_RBG    False        True
# ..                                                ...      ...         ...
# 63        20210831_KAO_HILIC_T1060M_20210408_10wk_RBG    False        True
# 64         20210831_KAO_HILIC_T1102M_20210327_8wk_FBG    False        True
# 65         20210831_KAO_HILIC_T1074M_20210322_8wk_FBG    False        True
# 66         20210831_KAO_HILIC_T1082M_20210401_9wk_RBG    False        True
# 67                  20210831_KAO_HILIC_human_plasma_5     True       False
#
#     blank_file  animal  week bg_type glucose_tolerance
# 0         True     NaN   NaN     NaN               NaN
# 1         True     NaN   NaN     NaN               NaN
# 2         True     NaN   NaN     NaN               NaN
# 3        False     NaN   NaN     NaN               NaN
# 4        False  1060.0   9.0     RBG          impaired
# ..         ...     ...   ...     ...               ...
# 63       False  1060.0  10.0     RBG          impaired
# 64       False  1102.0   8.0     FBG          impaired
# 65       False  1074.0   8.0     FBG          impaired
# 66       False  1082.0   9.0     RBG          diabetic
# 67       False     NaN   NaN     NaN               NaN
#
# [68 rows x 10 columns]

# %%
metabolomics_seq = pd.read_csv(r'..\data\metadata\20210831_KAO_HILIC_Huishi_sequence.csv',
                               skiprows=1)

pos = pd.read_csv(r'..\data\search\msdial\pos_alignment\Area_1_2021931826.txt', 
                     skiprows=4, sep='\t', index_col=0)
pos
# Out:
#               Average Rt(min)  Average Mz Metabolite name Adduct type  \
# Alignment ID
# 0                      17.980    70.06570         Unknown      [M+H]+
# 1                      13.068    70.06570         Unknown      [M+H]+
# 2                      17.361    70.06573         Unknown      [M+H]+
# 3                       2.006    70.06573         Unknown      [M+H]+
# 4                       5.374    70.06574         Unknown      [M+H]+
# ...                       ...         ...             ...         ...
# 21382                   1.548   894.59845         Unknown      [M+H]+
# 21383                   1.358   894.75348         Unknown     [M+Na]+
# 21384                   1.379   897.77325         Unknown      [M+H]+
# 21385                   1.682   898.58063         Unknown      [M+H]+
# 21386                   1.349   899.74109         Unknown      [M+H]+
#
#                                            Post curation result  Fill %  \
# Alignment ID
# 0                                                           NaN   0.015
# 1             found in higher mz's MsMs_950; found in higher...   0.735
# 2                                                           NaN   0.103
# 3             similar chromatogram in higher mz_6446; simila...   0.059
# 4                                                           NaN   0.074
# ...                                                         ...     ...
# 21382                                                       NaN   0.044
# 21383         adduct linked to 21300_[M+H]+; adduct linked t...   0.882
# 21384                                                       NaN   0.088
# 21385                                                       NaN   0.015
# 21386                                                       NaN   0.015
#
#               MS/MS assigned  Reference RT  Reference m/z Formula  ...  \
# Alignment ID                                                       ...
# 0                      False           NaN            NaN     NaN  ...
# 1                      False           NaN            NaN     NaN  ...
# 2                      False           NaN            NaN     NaN  ...
# 3                      False           NaN            NaN     NaN  ...
# 4                      False           NaN            NaN     NaN  ...
# ...                      ...           ...            ...     ...  ...
# 21382                  False           NaN            NaN     NaN  ...
# 21383                   True           NaN            NaN     NaN  ...
# 21384                  False           NaN            NaN     NaN  ...
# 21385                  False           NaN            NaN     NaN  ...
# 21386                  False           NaN            NaN     NaN  ...
#
#              20210831_KAO_HILIC_T1101M_20210413_10wk_RBG  \
# Alignment ID
# 0                                                  45086
# 1                                                 377486
# 2                                                 738587
# 3                                                 170777
# 4                                                 349644
# ...                                                  ...
# 21382                                             116451
# 21383                                             955584
# 21384                                             820788
# 21385                                                  0
# 21386                                                  0
#
#              20210831_KAO_HILIC_T1102M_20210327_8wk_FBG  \
# Alignment ID
# 0                                                 66506
# 1                                                275506
# 2                                                401786
# 3                                                235339
# 4                                                 97814
# ...                                                 ...
# 21382                                                 0
# 21383                                           1475695
# 21384                                            838276
# 21385                                            156820
# 21386                                                 0
#
#              20210831_KAO_HILIC_T1102M_20210402_9wk_FBG  \
# Alignment ID
# 0                                                 40004
# 1                                                240079
# 2                                                307830
# 3                                                 64572
# 4                                                471873
# ...                                                 ...
# 21382                                                 0
# 21383                                           2477724
# 21384                                           1568833
# 21385                                                 0
# 21386                                                 0
#
#               20210831_KAO_HILIC_T1102M_20210406_9wk_RBG  \
# Alignment ID
# 0                                                  95623
# 1                                                 355702
# 2                                                 215860
# 3                                                  94949
# 4                                                 417413
# ...                                                  ...
# 21382                                             116333
# 21383                                            1242535
# 21384                                            1497694
# 21385                                                  0
# 21386                                                  0
#
#               20210831_KAO_HILIC_T1102M_20210410_10wk_FBG  \
# Alignment ID
# 0                                                   36121
# 1                                                  265254
# 2                                                  440384
# 3                                                   38604
# 4                                                  618698
# ...                                                   ...
# 21382                                              112553
# 21383                                             1975012
# 21384                                             1264850
# 21385                                                   0
# 21386                                                   0
#
#               20210831_KAO_HILIC_T1102M_20210413_10wk_RBG  \
# Alignment ID
# 0                                                   41105
# 1                                                  396101
# 2                                                  600481
# 3                                                   22061
# 4                                                   46763
# ...                                                   ...
# 21382                                              151725
# 21383                                             1133486
# 21384                                             1218647
# 21385                                                   0
# 21386                                               22733
#
#               20210831_KAO_HILIC_T112M_20210330_8wk_RBG  \
# Alignment ID
# 0                                                233175
# 1                                                340758
# 2                                                672270
# 3                                                  1485
# 4                                                238769
# ...                                                 ...
# 21382                                                 0
# 21383                                            592283
# 21384                                            834281
# 21385                                                 0
# 21386                                                 0
#
#               20210831_KAO_HILIC_T193M20210406_9wk_RBG             1  \
# Alignment ID
# 0                                               335375  1.460943e+05
# 1                                               449559  3.151393e+05
# 2                                               620394  4.846335e+05
# 3                                               193892  1.407389e+05
# 4                                               636552  3.295410e+05
# ...                                                ...           ...
# 21382                                            34850  4.458349e+04
# 21383                                          1047666  1.034605e+06
# 21384                                          1014824  8.745012e+05
# 21385                                                0  4.155845e+04
# 21386                                                0  1.025098e+04
#
#                         1.1
# Alignment ID
# 0              97831.170925
# 1             107334.863624
# 2             221611.902910
# 3             152855.540782
# 4             185665.566415
# ...                     ...
# 21382          64611.251535
# 21383         733262.850754
# 21384         547126.069136
# 21385          98705.819221
# 21386          32782.120021
#
# [21387 rows x 101 columns]

# %%
pos.sort_values?

# %%
pos[pos['Fill %'] > 0.3].sort_values(by=['Fill %'], ascending=False)
# Out:
#               Average Rt(min)  Average Mz  \
# Alignment ID
# 17314                   1.468   500.37903
# 15913                   1.479   442.33740
# 5190                    2.040   195.12280
# 10950                   1.548   309.22705
# 12460                  10.428   344.98465
# ...                       ...         ...
# 20528                  16.988   750.89697
# 16828                   2.904   476.27545
# 20580                   6.941   758.56921
# 16880                   2.609   479.33432
# 14282                   1.458   394.28992
#
#                                                 Metabolite name Adduct type  \
# Alignment ID
# 17314                                                   Unknown      [M+H]+
# 15913                                                   Unknown    [M+NH4]+
# 5190          w/o MS2:Hydroxypyridin + C5H10NO or 6-Hydroxyp...      [M+H]+
# 10950                                                   Unknown      [M+H]+
# 12460                                                   Unknown     [M+Na]+
# ...                                                         ...         ...
# 20528                                                   Unknown      [M+H]+
# 16828                          w/o MS2:LPE 18:3; PlaSMA ID-2582      [M+H]+
# 20580                                                   Unknown      [M+H]+
# 16880         w/o MS2:NCGC00380758-01!(2S,3R,10R,13R,14S)-17...      [M+H]+
# 14282         w/o MS2:NCGC00180855-02_C23H36O4_2-Pentenoic a...      [M+H]+
#
#                                            Post curation result  Fill %  \
# Alignment ID
# 17314                                                       NaN   1.000
# 15913                             adduct linked to 15387_[M+H]+   1.000
# 5190          adduct linked to 5998_[M+NH4]+; similar chroma...   1.000
# 10950                            adduct linked to 11915_[M+Na]+   1.000
# 12460                             adduct linked to 11557_[M+H]+   1.000
# ...                                                         ...     ...
# 20528                                                       NaN   0.309
# 16828                                                       NaN   0.309
# 20580                                                       NaN   0.309
# 16880                                                       NaN   0.309
# 14282         ion correlated with 13714; ion correlated with...   0.309
#
#               MS/MS assigned  Reference RT  Reference m/z     Formula  ...  \
# Alignment ID                                                           ...
# 17314                  False           NaN            NaN         NaN  ...
# 15913                  False           NaN            NaN         NaN  ...
# 5190                    True          1.80      195.11369  C10H14N2O2  ...
# 10950                   True           NaN            NaN         NaN  ...
# 12460                  False           NaN            NaN         NaN  ...
# ...                      ...           ...            ...         ...  ...
# 20528                  False           NaN            NaN         NaN  ...
# 16828                  False          8.73      476.27560  C23H42NO7P  ...
# 20580                   True           NaN            NaN         NaN  ...
# 16880                  False           NaN      479.33670    C28H46O6  ...
# 14282                  False           NaN      394.29520    C23H36O4  ...
#
#              20210831_KAO_HILIC_T1101M_20210413_10wk_RBG  \
# Alignment ID
# 17314                                            1474554
# 15913                                             720119
# 5190                                            11735219
# 10950                                            1253270
# 12460                                            3142368
# ...                                                  ...
# 20528                                             105467
# 16828                                             345372
# 20580                                            4598402
# 16880                                             963902
# 14282                                            2078683
#
#              20210831_KAO_HILIC_T1102M_20210327_8wk_FBG  \
# Alignment ID
# 17314                                           1364279
# 15913                                            732460
# 5190                                            7250998
# 10950                                           1370001
# 12460                                            560288
# ...                                                 ...
# 20528                                             85054
# 16828                                            116643
# 20580                                            554621
# 16880                                            255465
# 14282                                           2625864
#
#              20210831_KAO_HILIC_T1102M_20210402_9wk_FBG  \
# Alignment ID
# 17314                                           1213179
# 15913                                            934112
# 5190                                            9251689
# 10950                                           1106375
# 12460                                           2089829
# ...                                                 ...
# 20528                                            102911
# 16828                                            330724
# 20580                                           2768398
# 16880                                            553130
# 14282                                           2488733
#
#               20210831_KAO_HILIC_T1102M_20210406_9wk_RBG  \
# Alignment ID
# 17314                                            1439639
# 15913                                             841123
# 5190                                             8830203
# 10950                                            1216346
# 12460                                             940517
# ...                                                  ...
# 20528                                             101116
# 16828                                             335322
# 20580                                            1204539
# 16880                                              33287
# 14282                                            1971140
#
#               20210831_KAO_HILIC_T1102M_20210410_10wk_FBG  \
# Alignment ID
# 17314                                             1542136
# 15913                                              924685
# 5190                                             10082091
# 10950                                             1759354
# 12460                                             1856257
# ...                                                   ...
# 20528                                              100714
# 16828                                              367000
# 20580                                             1436548
# 16880                                              624430
# 14282                                             1481254
#
#               20210831_KAO_HILIC_T1102M_20210413_10wk_RBG  \
# Alignment ID
# 17314                                             1414286
# 15913                                              860294
# 5190                                             11074877
# 10950                                             1367105
# 12460                                              448384
# ...                                                   ...
# 20528                                              120776
# 16828                                              543566
# 20580                                             1997302
# 16880                                               95246
# 14282                                             2264286
#
#               20210831_KAO_HILIC_T112M_20210330_8wk_RBG  \
# Alignment ID
# 17314                                           1226383
# 15913                                           1009061
# 5190                                            7149584
# 10950                                           1052589
# 12460                                            368447
# ...                                                 ...
# 20528                                             97923
# 16828                                            446877
# 20580                                           1724818
# 16880                                            765894
# 14282                                           1830470
#
#               20210831_KAO_HILIC_T193M20210406_9wk_RBG             1  \
# Alignment ID
# 17314                                          1467288  1.370382e+06
# 15913                                           746711  8.688247e+05
# 5190                                           8475507  7.708673e+06
# 10950                                          1171096  1.198347e+06
# 12460                                           544410  1.331541e+06
# ...                                                ...           ...
# 20528                                           152027  1.233550e+05
# 16828                                           407349  2.856763e+05
# 20580                                           854717  1.223739e+06
# 16880                                            95412  5.340026e+05
# 14282                                          2022324  1.901093e+06
#
#                        1.1
# Alignment ID
# 17314         4.182820e+05
# 15913         2.517021e+05
# 5190          3.698846e+06
# 10950         2.834988e+05
# 12460         1.159642e+06
# ...                    ...
# 20528         1.135095e+05
# 16828         1.368371e+05
# 20580         1.077343e+06
# 16880         2.652352e+05
# 14282         1.436113e+06
#
# [2662 rows x 101 columns]

# %% [markdown]
# ### rawfile names have some problems, so make a metabolomics file_grouping lookup table similar to lipids

# %%
bad_file = '20210831_KAO_HILIC_ACN'  # file size is only 800 kB and it failed to convert in MSConvert
typo_files = {'20210831_KAO_HILIC_T193M20210406_9wk_RBG': '20210831_KAO_HILIC_T1093M_20210406_9wk_RBG',
              '20210831_KAO_HILIC_T1092_20210410_10wk_FBG': '20210831_KAO_HILIC_T1092M_20210410_10wk_FBG',
              '20210831_KAO_HILIC_T112M_20210330_8wk_RBG': '20210831_KAO_HILIC_T1102M_20210330_8wk_RBG',
              '20210831_KAO_HILIC_T1092M_20210402_wk_FBG': '20210831_KAO_HILIC_T1092M_20210402_9wk_FBG'}
qc_files = list(metabolomics_seq[metabolomics_seq['File Name'].str.contains('human')]['File Name'].values)
blank_files = ['20210831_KAO_HILIC_ACN', '20210831_KAO_HILIC_ACN_20210831232610',
               '20210831_KAO_HILIC_extraction_blank_1', '20210831_KAO_HILIC_extraction_blank_1_20210901004002']

# %%
list(metabolomics_seq[metabolomics_seq['File Name'].str.contains('human')]['File Name'].values)
# Out:
# ['20210831_KAO_HILIC_human_plasma_1',
#  '20210831_KAO_HILIC_human_plasma_2',
#  '20210831_KAO_HILIC_human_plasma_3',
#  '20210831_KAO_HILIC_human_plasma_4',
#  '20210831_KAO_HILIC_human_plasma_5']

# %%
[1,2] + [3,4]
# Out:
# [1, 2, 3, 4]

# %%
original_quant_filenames = list(metabolomics_seq[~metabolomics_seq['File Name'].isin(qc_files + blank_files)]['File Name'].values)
original_quant_filenames

modified_quant_filenames = []
for file in original_quant_filenames:
    if file in typo_files:
        modified_quant_filenames.append(typo_files[file])
    else:
        modified_quant_filenames.append(file)

file_sample_info = [(x, 
                     x.split('HILIC_T')[1].split('M_2021')[0], 
                     x.split('wk_')[0].split('_')[-1],
                     x.split('_')[-1]) for x in modified_quant_filenames]
df = pd.DataFrame(file_sample_info, columns=['modified_file_names', 'animal', 'week', 'bg_type'])
df['original_file_names'] = original_quant_filenames
df
# Out:
#                             modified_file_names animal week bg_type  \
# 0    20210831_KAO_HILIC_T1060M_20210401_9wk_RBG   1060    9     RBG
# 1    20210831_KAO_HILIC_T1076M_20210329_9wk_FBG   1076    9     FBG
# 2   20210831_KAO_HILIC_T1092M_20210413_10wk_RBG   1092   10     RBG
# 3    20210831_KAO_HILIC_T1101M_20210327_8wk_FBG   1101    8     FBG
# 4   20210831_KAO_HILIC_T1062M_20210405_10wk_FBG   1062   10     FBG
# 5   20210831_KAO_HILIC_T1101M_20210413_10wk_RBG   1101   10     RBG
# 6   20210831_KAO_HILIC_T1082M_20210408_10wk_RBG   1082   10     RBG
# 7    20210831_KAO_HILIC_T1092M_20210327_8wk_FBG   1092    8     FBG
# 8    20210831_KAO_HILIC_T1060M_20210322_8wk_FBG   1060    8     FBG
# 9    20210831_KAO_HILIC_T1093M_20210330_8wk_RBG   1093    8     RBG
# 10   20210831_KAO_HILIC_T1074M_20210401_9wk_RBG   1074    9     RBG
# 11   20210831_KAO_HILIC_T1102M_20210402_9wk_FBG   1102    9     FBG
# 12   20210831_KAO_HILIC_T1082M_20210329_9wk_FBG   1082    9     FBG
# 13   20210831_KAO_HILIC_T1092M_20210406_9wk_RBG   1092    9     RBG
# 14  20210831_KAO_HILIC_T1093M_20210410_10wk_FBG   1093   10     FBG
# 15  20210831_KAO_HILIC_T1060M_20210405_10wk_FBG   1060   10     FBG
# 16  20210831_KAO_HILIC_T1076M_20210405_10wk_FBG   1076   10     FBG
# 17   20210831_KAO_HILIC_T1101M_20210406_9wk_RBG   1101    9     RBG
# 18  20210831_KAO_HILIC_T1102M_20210413_10wk_RBG   1102   10     RBG
# 19   20210831_KAO_HILIC_T1074M_20210325_8wk_RBG   1074    8     RBG
# 20   20210831_KAO_HILIC_T1060M_20210329_9wk_FBG   1060    9     FBG
# 21   20210831_KAO_HILIC_T1091M_20210406_9wk_RBG   1091    9     RBG
# 22   20210831_KAO_HILIC_T1101M_20210330_8wk_RBG   1101    8     RBG
# 23   20210831_KAO_HILIC_T1091M_20210402_9wk_FBG   1091    9     FBG
# 24  20210831_KAO_HILIC_T1076M_20210408_10wk_RBG   1076   10     RBG
# 25   20210831_KAO_HILIC_T1092M_20210402_9wk_FBG   1092    9     FBG
# 26   20210831_KAO_HILIC_T1093M_20210327_8wk_FBG   1093    8     FBG
# 27  20210831_KAO_HILIC_T1091M_20210413_10wk_RBG   1091   10     RBG
# 28   20210831_KAO_HILIC_T1062M_20210325_8wk_RBG   1062    8     RBG
# 29   20210831_KAO_HILIC_T1093M_20210406_9wk_RBG   1093    9     RBG
# 30   20210831_KAO_HILIC_T1082M_20210322_8wk_FBG   1082    8     FBG
# 31   20210831_KAO_HILIC_T1076M_20210322_8wk_FBG   1076    8     FBG
# 32   20210831_KAO_HILIC_T1102M_20210330_8wk_RBG   1102    8     RBG
# 33   20210831_KAO_HILIC_T1091M_20210330_8wk_RBG   1091    8     RBG
# 34  20210831_KAO_HILIC_T1082M_20210405_10wk_FBG   1082   10     FBG
# 35   20210831_KAO_HILIC_T1062M_20210401_9wk_RBG   1062    9     RBG
# 36  20210831_KAO_HILIC_T1092M_20210410_10wk_FBG   1092   10     FBG
# 37   20210831_KAO_HILIC_T1101M_20210402_9wk_FBG   1101    9     FBG
# 38  20210831_KAO_HILIC_T1093M_20210413_10wk_RBG   1093   10     RBG
# 39   20210831_KAO_HILIC_T1074M_20210329_9wk_FBG   1074    9     FBG
# 40   20210831_KAO_HILIC_T1076M_20210325_8wk_RBG   1076    8     RBG
# 41  20210831_KAO_HILIC_T1102M_20210410_10wk_FBG   1102   10     FBG
# 42  20210831_KAO_HILIC_T1074M_20210408_10wk_RBG   1074   10     RBG
# 43   20210831_KAO_HILIC_T1093M_20210402_9wk_FBG   1093    9     FBG
# 44  20210831_KAO_HILIC_T1062M_20210408_10wk_RBG   1062   10     RBG
# 45   20210831_KAO_HILIC_T1082M_20210325_8wk_RBG   1082    8     RBG
# 46  20210831_KAO_HILIC_T1101M_20210410_10wk_FBG   1101   10     FBG
# 47   20210831_KAO_HILIC_T1062M_20210329_9wk_FBG   1062    9     FBG
# 48  20210831_KAO_HILIC_T1091M_20210410_10wk_FBG   1091   10     FBG
# 49  20210831_KAO_HILIC_T1074M_20210405_10wk_FBG   1074   10     FBG
# 50   20210831_KAO_HILIC_T1076M_20210401_9wk_RBG   1076    9     RBG
# 51   20210831_KAO_HILIC_T1060M_20210325_8wk_RBG   1060    8     RBG
# 52   20210831_KAO_HILIC_T1102M_20210406_9wk_RBG   1102    9     RBG
# 53   20210831_KAO_HILIC_T1062M_20210322_8wk_FBG   1062    8     FBG
# 54   20210831_KAO_HILIC_T1092M_20210330_8wk_RBG   1092    8     RBG
# 55   20210831_KAO_HILIC_T1091M_20210327_8wk_FBG   1091    8     FBG
# 56  20210831_KAO_HILIC_T1060M_20210408_10wk_RBG   1060   10     RBG
# 57   20210831_KAO_HILIC_T1102M_20210327_8wk_FBG   1102    8     FBG
# 58   20210831_KAO_HILIC_T1074M_20210322_8wk_FBG   1074    8     FBG
# 59   20210831_KAO_HILIC_T1082M_20210401_9wk_RBG   1082    9     RBG
#
#                             original_file_names
# 0    20210831_KAO_HILIC_T1060M_20210401_9wk_RBG
# 1    20210831_KAO_HILIC_T1076M_20210329_9wk_FBG
# 2   20210831_KAO_HILIC_T1092M_20210413_10wk_RBG
# 3    20210831_KAO_HILIC_T1101M_20210327_8wk_FBG
# 4   20210831_KAO_HILIC_T1062M_20210405_10wk_FBG
# 5   20210831_KAO_HILIC_T1101M_20210413_10wk_RBG
# 6   20210831_KAO_HILIC_T1082M_20210408_10wk_RBG
# 7    20210831_KAO_HILIC_T1092M_20210327_8wk_FBG
# 8    20210831_KAO_HILIC_T1060M_20210322_8wk_FBG
# 9    20210831_KAO_HILIC_T1093M_20210330_8wk_RBG
# 10   20210831_KAO_HILIC_T1074M_20210401_9wk_RBG
# 11   20210831_KAO_HILIC_T1102M_20210402_9wk_FBG
# 12   20210831_KAO_HILIC_T1082M_20210329_9wk_FBG
# 13   20210831_KAO_HILIC_T1092M_20210406_9wk_RBG
# 14  20210831_KAO_HILIC_T1093M_20210410_10wk_FBG
# 15  20210831_KAO_HILIC_T1060M_20210405_10wk_FBG
# 16  20210831_KAO_HILIC_T1076M_20210405_10wk_FBG
# 17   20210831_KAO_HILIC_T1101M_20210406_9wk_RBG
# 18  20210831_KAO_HILIC_T1102M_20210413_10wk_RBG
# 19   20210831_KAO_HILIC_T1074M_20210325_8wk_RBG
# 20   20210831_KAO_HILIC_T1060M_20210329_9wk_FBG
# 21   20210831_KAO_HILIC_T1091M_20210406_9wk_RBG
# 22   20210831_KAO_HILIC_T1101M_20210330_8wk_RBG
# 23   20210831_KAO_HILIC_T1091M_20210402_9wk_FBG
# 24  20210831_KAO_HILIC_T1076M_20210408_10wk_RBG
# 25    20210831_KAO_HILIC_T1092M_20210402_wk_FBG
# 26   20210831_KAO_HILIC_T1093M_20210327_8wk_FBG
# 27  20210831_KAO_HILIC_T1091M_20210413_10wk_RBG
# 28   20210831_KAO_HILIC_T1062M_20210325_8wk_RBG
# 29     20210831_KAO_HILIC_T193M20210406_9wk_RBG
# 30   20210831_KAO_HILIC_T1082M_20210322_8wk_FBG
# 31   20210831_KAO_HILIC_T1076M_20210322_8wk_FBG
# 32    20210831_KAO_HILIC_T112M_20210330_8wk_RBG
# 33   20210831_KAO_HILIC_T1091M_20210330_8wk_RBG
# 34  20210831_KAO_HILIC_T1082M_20210405_10wk_FBG
# 35   20210831_KAO_HILIC_T1062M_20210401_9wk_RBG
# 36   20210831_KAO_HILIC_T1092_20210410_10wk_FBG
# 37   20210831_KAO_HILIC_T1101M_20210402_9wk_FBG
# 38  20210831_KAO_HILIC_T1093M_20210413_10wk_RBG
# 39   20210831_KAO_HILIC_T1074M_20210329_9wk_FBG
# 40   20210831_KAO_HILIC_T1076M_20210325_8wk_RBG
# 41  20210831_KAO_HILIC_T1102M_20210410_10wk_FBG
# 42  20210831_KAO_HILIC_T1074M_20210408_10wk_RBG
# 43   20210831_KAO_HILIC_T1093M_20210402_9wk_FBG
# 44  20210831_KAO_HILIC_T1062M_20210408_10wk_RBG
# 45   20210831_KAO_HILIC_T1082M_20210325_8wk_RBG
# 46  20210831_KAO_HILIC_T1101M_20210410_10wk_FBG
# 47   20210831_KAO_HILIC_T1062M_20210329_9wk_FBG
# 48  20210831_KAO_HILIC_T1091M_20210410_10wk_FBG
# 49  20210831_KAO_HILIC_T1074M_20210405_10wk_FBG
# 50   20210831_KAO_HILIC_T1076M_20210401_9wk_RBG
# 51   20210831_KAO_HILIC_T1060M_20210325_8wk_RBG
# 52   20210831_KAO_HILIC_T1102M_20210406_9wk_RBG
# 53   20210831_KAO_HILIC_T1062M_20210322_8wk_FBG
# 54   20210831_KAO_HILIC_T1092M_20210330_8wk_RBG
# 55   20210831_KAO_HILIC_T1091M_20210327_8wk_FBG
# 56  20210831_KAO_HILIC_T1060M_20210408_10wk_RBG
# 57   20210831_KAO_HILIC_T1102M_20210327_8wk_FBG
# 58   20210831_KAO_HILIC_T1074M_20210322_8wk_FBG
# 59   20210831_KAO_HILIC_T1082M_20210401_9wk_RBG

# %%
df[df[0].str.contains('1092')]
# Out:
#                                               0     1   2    3  \
# 2   20210831_KAO_HILIC_T1092M_20210413_10wk_RBG  1092  10  RBG
# 7    20210831_KAO_HILIC_T1092M_20210327_8wk_FBG  1092   8  FBG
# 13   20210831_KAO_HILIC_T1092M_20210406_9wk_RBG  1092   9  RBG
# 25   20210831_KAO_HILIC_T1092M_20210402_9wk_FBG  1092   9  FBG
# 36  20210831_KAO_HILIC_T1092M_20210410_10wk_FBG  1092  10  FBG
# 54   20210831_KAO_HILIC_T1092M_20210330_8wk_RBG  1092   8  RBG
#
#                                           extra
# 2   20210831_KAO_HILIC_T1092M_20210413_10wk_RBG
# 7    20210831_KAO_HILIC_T1092M_20210327_8wk_FBG
# 13   20210831_KAO_HILIC_T1092M_20210406_9wk_RBG
# 25    20210831_KAO_HILIC_T1092M_20210402_wk_FBG
# 36   20210831_KAO_HILIC_T1092_20210410_10wk_FBG
# 54   20210831_KAO_HILIC_T1092M_20210330_8wk_RBG

# %%
list(metabolomics_seq['File Name'])
# Out:
# ['20210831_KAO_HILIC_ACN',
#  '20210831_KAO_HILIC_ACN_20210831232610',
#  '20210831_KAO_HILIC_extraction_blank_1',
#  '20210831_KAO_HILIC_extraction_blank_1_20210901004002',
#  '20210831_KAO_HILIC_human_plasma_1',
#  '20210831_KAO_HILIC_T1060M_20210401_9wk_RBG',
#  '20210831_KAO_HILIC_T1076M_20210329_9wk_FBG',
#  '20210831_KAO_HILIC_T1092M_20210413_10wk_RBG',
#  '20210831_KAO_HILIC_T1101M_20210327_8wk_FBG',
#  '20210831_KAO_HILIC_T1062M_20210405_10wk_FBG',
#  '20210831_KAO_HILIC_T1101M_20210413_10wk_RBG',
#  '20210831_KAO_HILIC_T1082M_20210408_10wk_RBG',
#  '20210831_KAO_HILIC_T1092M_20210327_8wk_FBG',
#  '20210831_KAO_HILIC_T1060M_20210322_8wk_FBG',
#  '20210831_KAO_HILIC_T1093M_20210330_8wk_RBG',
#  '20210831_KAO_HILIC_T1074M_20210401_9wk_RBG',
#  '20210831_KAO_HILIC_T1102M_20210402_9wk_FBG',
#  '20210831_KAO_HILIC_T1082M_20210329_9wk_FBG',
#  '20210831_KAO_HILIC_T1092M_20210406_9wk_RBG',
#  '20210831_KAO_HILIC_T1093M_20210410_10wk_FBG',
#  '20210831_KAO_HILIC_T1060M_20210405_10wk_FBG',
#  '20210831_KAO_HILIC_T1076M_20210405_10wk_FBG',
#  '20210831_KAO_HILIC_human_plasma_2',
#  '20210831_KAO_HILIC_T1101M_20210406_9wk_RBG',
#  '20210831_KAO_HILIC_T1102M_20210413_10wk_RBG',
#  '20210831_KAO_HILIC_T1074M_20210325_8wk_RBG',
#  '20210831_KAO_HILIC_T1060M_20210329_9wk_FBG',
#  '20210831_KAO_HILIC_T1091M_20210406_9wk_RBG',
#  '20210831_KAO_HILIC_T1101M_20210330_8wk_RBG',
#  '20210831_KAO_HILIC_T1091M_20210402_9wk_FBG',
#  '20210831_KAO_HILIC_T1076M_20210408_10wk_RBG',
#  '20210831_KAO_HILIC_T1092M_20210402_wk_FBG',
#  '20210831_KAO_HILIC_T1093M_20210327_8wk_FBG',
#  '20210831_KAO_HILIC_T1091M_20210413_10wk_RBG',
#  '20210831_KAO_HILIC_T1062M_20210325_8wk_RBG',
#  '20210831_KAO_HILIC_T193M20210406_9wk_RBG',
#  '20210831_KAO_HILIC_T1082M_20210322_8wk_FBG',
#  '20210831_KAO_HILIC_T1076M_20210322_8wk_FBG',
#  '20210831_KAO_HILIC_human_plasma_3',
#  '20210831_KAO_HILIC_T112M_20210330_8wk_RBG',
#  '20210831_KAO_HILIC_T1091M_20210330_8wk_RBG',
#  '20210831_KAO_HILIC_T1082M_20210405_10wk_FBG',
#  '20210831_KAO_HILIC_T1062M_20210401_9wk_RBG',
#  '20210831_KAO_HILIC_T1092_20210410_10wk_FBG',
#  '20210831_KAO_HILIC_T1101M_20210402_9wk_FBG',
#  '20210831_KAO_HILIC_T1093M_20210413_10wk_RBG',
#  '20210831_KAO_HILIC_T1074M_20210329_9wk_FBG',
#  '20210831_KAO_HILIC_T1076M_20210325_8wk_RBG',
#  '20210831_KAO_HILIC_T1102M_20210410_10wk_FBG',
#  '20210831_KAO_HILIC_T1074M_20210408_10wk_RBG',
#  '20210831_KAO_HILIC_T1093M_20210402_9wk_FBG',
#  '20210831_KAO_HILIC_T1062M_20210408_10wk_RBG',
#  '20210831_KAO_HILIC_T1082M_20210325_8wk_RBG',
#  '20210831_KAO_HILIC_human_plasma_4',
#  '20210831_KAO_HILIC_T1101M_20210410_10wk_FBG',
#  '20210831_KAO_HILIC_T1062M_20210329_9wk_FBG',
#  '20210831_KAO_HILIC_T1091M_20210410_10wk_FBG',
#  '20210831_KAO_HILIC_T1074M_20210405_10wk_FBG',
#  '20210831_KAO_HILIC_T1076M_20210401_9wk_RBG',
#  '20210831_KAO_HILIC_T1060M_20210325_8wk_RBG',
#  '20210831_KAO_HILIC_T1102M_20210406_9wk_RBG',
#  '20210831_KAO_HILIC_T1062M_20210322_8wk_FBG',
#  '20210831_KAO_HILIC_T1092M_20210330_8wk_RBG',
#  '20210831_KAO_HILIC_T1091M_20210327_8wk_FBG',
#  '20210831_KAO_HILIC_T1060M_20210408_10wk_RBG',
#  '20210831_KAO_HILIC_T1102M_20210327_8wk_FBG',
#  '20210831_KAO_HILIC_T1074M_20210322_8wk_FBG',
#  '20210831_KAO_HILIC_T1082M_20210401_9wk_RBG',
#  '20210831_KAO_HILIC_human_plasma_5']
