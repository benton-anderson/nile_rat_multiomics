# %%
import dateutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fr_raw = pd.read_csv(r'..\data\search\peak_finder\Final_Results.csv').dropna(axis=1, how='all')
fr_norm = pd.read_csv(r'..\data\processed\lipidomics_linregress_normalized_data.csv')
fr_filt = pd.read_csv(r'..\data\processed\lipidomics_normalized_filtered_data.csv', index_col=0)
file_grouping = pd.read_csv(r'..\data\metadata\file_grouping.csv', index_col=0)

fr_quant_filenames_in_analytical_order = file_grouping[file_grouping['quant_file'] == True]['fr_name'].to_list()

animals_used = [1091, 1093, 1060, 1062, 1074, 1092, 1102, 1076, 1082, 1101]
diabetic = [1076, 1082, 1101]
impaired = [1060, 1062, 1074, 1092, 1102]
normal = [1091, 1093]
bg_dict = {'diabetic': diabetic, 'impaired': impaired, 'normal': normal}
animal_to_tolerance_dict = {1076: 'diabetic', 1082: 'diabetic',1101: 'diabetic',
                            1060: 'impaired', 1062: 'impaired', 1074: 'impaired', 1092: 'impaired', 1102: 'impaired', 
                            1091: 'normal', 1093: 'normal',}

obs = pd.read_excel(r'..\data\metadata\20210421_FBGRBGOGTT_Huishi sample sheet.xlsx', sheet_name='cleaned')
obs['animal'] = obs['animal'].str.strip('TM').astype('int')
obs['datetime'] = obs['when'].apply(dateutil.parser.parse)
animal_phenotypes = pd.read_excel(r'..\data\metadata\20210421_FBGRBGOGTT_Huishi sample sheet.xlsx', sheet_name='animal phenotypes')
animal_phenotypes['animal'] = animal_phenotypes['animal'].str.strip('TM').astype('int')

# %%
np.log2(fr_filt[fr_quant_filenames_in_analytical_order])
# Out:
#                            20210729_AJ_Toh_RatBloodGlucose_T1076M_20210405_10wk_FBG.raw (F27)  \
# Unique Identifier
# unknown_679.05463_0.536                                            20.405355
# unknown_641.1087_0.537                                             21.533648
# unknown_951.15973_0.541                                            20.665848
# unknown_329.03067_0.542                                            24.400930
# unknown_969.13147_0.544                                            19.378685
# ...                                                                      ...
# unknown_897.82532_20.148                                           18.897008
# unknown_974.9118_20.163                                            16.810111
# unknown_593.58716_20.175                                           17.724121
# unknown_871.80945_20.196                                           18.400646
# unknown_1003.93829_20.435                                          16.655211
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1062M_20210322_8wk_FBG.raw (F9)  \
# Unique Identifier
# unknown_679.05463_0.536                                            23.313111
# unknown_641.1087_0.537                                             24.586227
# unknown_951.15973_0.541                                            23.731244
# unknown_329.03067_0.542                                            26.811664
# unknown_969.13147_0.544                                            22.709669
# ...                                                                      ...
# unknown_897.82532_20.148                                           19.348489
# unknown_974.9118_20.163                                            17.364343
# unknown_593.58716_20.175                                           19.240306
# unknown_871.80945_20.196                                           18.585339
# unknown_1003.93829_20.435                                          16.313637
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1093M_20210402_9wk_FBG.raw (F49)  \
# Unique Identifier
# unknown_679.05463_0.536                                            23.218699
# unknown_641.1087_0.537                                             24.375151
# unknown_951.15973_0.541                                            23.038733
# unknown_329.03067_0.542                                            26.708762
# unknown_969.13147_0.544                                            21.722467
# ...                                                                      ...
# unknown_897.82532_20.148                                           21.529536
# unknown_974.9118_20.163                                            20.099612
# unknown_593.58716_20.175                                           21.430516
# unknown_871.80945_20.196                                           20.968101
# unknown_1003.93829_20.435                                          19.339229
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1060M_20210325_8wk_RBG.raw (F4)  \
# Unique Identifier
# unknown_679.05463_0.536                                            24.012349
# unknown_641.1087_0.537                                             25.685664
# unknown_951.15973_0.541                                            24.916555
# unknown_329.03067_0.542                                            25.977120
# unknown_969.13147_0.544                                            23.985839
# ...                                                                      ...
# unknown_897.82532_20.148                                           17.921098
# unknown_974.9118_20.163                                            18.430542
# unknown_593.58716_20.175                                           17.488155
# unknown_871.80945_20.196                                           16.202162
# unknown_1003.93829_20.435                                          17.985491
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1091M_20210410_10wk_FBG.raw (F39)  \
# Unique Identifier
# unknown_679.05463_0.536                                            24.302356
# unknown_641.1087_0.537                                             25.422294
# unknown_951.15973_0.541                                            24.042666
# unknown_329.03067_0.542                                            27.313654
# unknown_969.13147_0.544                                            22.321161
# ...                                                                      ...
# unknown_897.82532_20.148                                           20.133479
# unknown_974.9118_20.163                                            17.986741
# unknown_593.58716_20.175                                           19.996615
# unknown_871.80945_20.196                                           19.778245
# unknown_1003.93829_20.435                                          17.357845
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1092M_20210406_9wk_RBG.raw (F44)  \
# Unique Identifier
# unknown_679.05463_0.536                                            23.901455
# unknown_641.1087_0.537                                             24.936916
# unknown_951.15973_0.541                                            24.162971
# unknown_329.03067_0.542                                            27.337061
# unknown_969.13147_0.544                                            23.184906
# ...                                                                      ...
# unknown_897.82532_20.148                                           17.824376
# unknown_974.9118_20.163                                            18.099621
# unknown_593.58716_20.175                                           17.383197
# unknown_871.80945_20.196                                           15.556400
# unknown_1003.93829_20.435                                          17.582655
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1093M_20210413_10wk_RBG.raw (F52)  \
# Unique Identifier
# unknown_679.05463_0.536                                            23.883301
# unknown_641.1087_0.537                                             24.779941
# unknown_951.15973_0.541                                            23.627979
# unknown_329.03067_0.542                                            27.415597
# unknown_969.13147_0.544                                            22.795191
# ...                                                                      ...
# unknown_897.82532_20.148                                           18.836779
# unknown_974.9118_20.163                                            18.145468
# unknown_593.58716_20.175                                           18.282680
# unknown_871.80945_20.196                                           16.603878
# unknown_1003.93829_20.435                                          17.887551
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1082M_20210405_10wk_FBG.raw (F33)  \
# Unique Identifier
# unknown_679.05463_0.536                                            23.387975
# unknown_641.1087_0.537                                             24.696276
# unknown_951.15973_0.541                                            24.085858
# unknown_329.03067_0.542                                            27.230430
# unknown_969.13147_0.544                                            22.878785
# ...                                                                      ...
# unknown_897.82532_20.148                                           19.255315
# unknown_974.9118_20.163                                            14.496938
# unknown_593.58716_20.175                                           19.507853
# unknown_871.80945_20.196                                           19.379093
# unknown_1003.93829_20.435                                          13.846921
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1060M_20210401_9wk_RBG.raw (F6)  \
# Unique Identifier
# unknown_679.05463_0.536                                            24.421692
# unknown_641.1087_0.537                                             25.054941
# unknown_951.15973_0.541                                            23.169508
# unknown_329.03067_0.542                                            27.598719
# unknown_969.13147_0.544                                            22.397716
# ...                                                                      ...
# unknown_897.82532_20.148                                           18.261890
# unknown_974.9118_20.163                                            18.854601
# unknown_593.58716_20.175                                           17.718258
# unknown_871.80945_20.196                                           16.494586
# unknown_1003.93829_20.435                                          18.466842
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1101M_20210402_9wk_FBG.raw (F55)  \
# Unique Identifier
# unknown_679.05463_0.536                                            23.463756
# unknown_641.1087_0.537                                             24.934805
# unknown_951.15973_0.541                                            24.010849
# unknown_329.03067_0.542                                            27.126653
# unknown_969.13147_0.544                                            22.703282
# ...                                                                      ...
# unknown_897.82532_20.148                                           19.685160
# unknown_974.9118_20.163                                            18.324624
# unknown_593.58716_20.175                                           19.526233
# unknown_871.80945_20.196                                           18.844052
# unknown_1003.93829_20.435                                          17.739443
#
#                            ...  \
# Unique Identifier          ...
# unknown_679.05463_0.536    ...
# unknown_641.1087_0.537     ...
# unknown_951.15973_0.541    ...
# unknown_329.03067_0.542    ...
# unknown_969.13147_0.544    ...
# ...                        ...
# unknown_897.82532_20.148   ...
# unknown_974.9118_20.163    ...
# unknown_593.58716_20.175   ...
# unknown_871.80945_20.196   ...
# unknown_1003.93829_20.435  ...
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1092M_20210410_10wk_FBG.raw (F45)  \
# Unique Identifier
# unknown_679.05463_0.536                                            22.462249
# unknown_641.1087_0.537                                             24.663849
# unknown_951.15973_0.541                                            23.452626
# unknown_329.03067_0.542                                            27.210668
# unknown_969.13147_0.544                                            22.602208
# ...                                                                      ...
# unknown_897.82532_20.148                                           18.604841
# unknown_974.9118_20.163                                            16.326408
# unknown_593.58716_20.175                                           18.815858
# unknown_871.80945_20.196                                           18.126555
# unknown_1003.93829_20.435                                          15.806144
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1082M_20210325_8wk_RBG.raw (F30)  \
# Unique Identifier
# unknown_679.05463_0.536                                            23.360916
# unknown_641.1087_0.537                                             23.700392
# unknown_951.15973_0.541                                            22.549975
# unknown_329.03067_0.542                                            26.194952
# unknown_969.13147_0.544                                            21.905509
# ...                                                                      ...
# unknown_897.82532_20.148                                           18.755897
# unknown_974.9118_20.163                                            19.046476
# unknown_593.58716_20.175                                           18.693961
# unknown_871.80945_20.196                                           17.059262
# unknown_1003.93829_20.435                                          19.437801
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1062M_20210325_8wk_RBG.raw (F10)  \
# Unique Identifier
# unknown_679.05463_0.536                                            22.399150
# unknown_641.1087_0.537                                             23.382317
# unknown_951.15973_0.541                                            23.249352
# unknown_329.03067_0.542                                            26.911119
# unknown_969.13147_0.544                                            22.226570
# ...                                                                      ...
# unknown_897.82532_20.148                                           18.996482
# unknown_974.9118_20.163                                            18.653201
# unknown_593.58716_20.175                                           18.778798
# unknown_871.80945_20.196                                           16.471090
# unknown_1003.93829_20.435                                          19.285159
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1102M_20210410_10wk_FBG.raw (F63)  \
# Unique Identifier
# unknown_679.05463_0.536                                            23.163419
# unknown_641.1087_0.537                                             24.385568
# unknown_951.15973_0.541                                            23.680978
# unknown_329.03067_0.542                                            26.805997
# unknown_969.13147_0.544                                            22.485669
# ...                                                                      ...
# unknown_897.82532_20.148                                           20.095162
# unknown_974.9118_20.163                                            18.635659
# unknown_593.58716_20.175                                           20.192346
# unknown_871.80945_20.196                                           19.560624
# unknown_1003.93829_20.435                                          18.341164
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1093M_20210330_8wk_RBG.raw (F48)  \
# Unique Identifier
# unknown_679.05463_0.536                                            22.737840
# unknown_641.1087_0.537                                             23.789670
# unknown_951.15973_0.541                                            23.989589
# unknown_329.03067_0.542                                            26.145097
# unknown_969.13147_0.544                                            22.208159
# ...                                                                      ...
# unknown_897.82532_20.148                                           17.759520
# unknown_974.9118_20.163                                            17.382575
# unknown_593.58716_20.175                                           17.113028
# unknown_871.80945_20.196                                           15.553916
# unknown_1003.93829_20.435                                          17.789158
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1074M_20210329_9wk_FBG.raw (F19)  \
# Unique Identifier
# unknown_679.05463_0.536                                            22.116533
# unknown_641.1087_0.537                                             22.248759
# unknown_951.15973_0.541                                            23.527507
# unknown_329.03067_0.542                                            26.638404
# unknown_969.13147_0.544                                            22.236114
# ...                                                                      ...
# unknown_897.82532_20.148                                           18.908638
# unknown_974.9118_20.163                                            17.575165
# unknown_593.58716_20.175                                           18.925197
# unknown_871.80945_20.196                                           17.922820
# unknown_1003.93829_20.435                                          16.157526
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1062M_20210401_9wk_RBG.raw (F14)  \
# Unique Identifier
# unknown_679.05463_0.536                                            23.352451
# unknown_641.1087_0.537                                             22.513249
# unknown_951.15973_0.541                                            24.002570
# unknown_329.03067_0.542                                            27.217392
# unknown_969.13147_0.544                                            23.151359
# ...                                                                      ...
# unknown_897.82532_20.148                                           18.093365
# unknown_974.9118_20.163                                            18.798950
# unknown_593.58716_20.175                                           17.773412
# unknown_871.80945_20.196                                           15.791324
# unknown_1003.93829_20.435                                          18.489770
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1101M_20210330_8wk_RBG.raw (F54)  \
# Unique Identifier
# unknown_679.05463_0.536                                            23.527438
# unknown_641.1087_0.537                                             24.558075
# unknown_951.15973_0.541                                            23.886203
# unknown_329.03067_0.542                                            26.970428
# unknown_969.13147_0.544                                            22.823820
# ...                                                                      ...
# unknown_897.82532_20.148                                           17.607114
# unknown_974.9118_20.163                                            16.704255
# unknown_593.58716_20.175                                           17.541022
# unknown_871.80945_20.196                                           15.832797
# unknown_1003.93829_20.435                                          15.604317
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1092M_20210330_8wk_RBG.raw (F42)  \
# Unique Identifier
# unknown_679.05463_0.536                                            23.858693
# unknown_641.1087_0.537                                             24.818525
# unknown_951.15973_0.541                                            24.069137
# unknown_329.03067_0.542                                            27.175265
# unknown_969.13147_0.544                                            21.750593
# ...                                                                      ...
# unknown_897.82532_20.148                                           17.326455
# unknown_974.9118_20.163                                            18.420810
# unknown_593.58716_20.175                                           16.974304
# unknown_871.80945_20.196                                           14.273751
# unknown_1003.93829_20.435                                          17.785595
#
#                            20210729_AJ_Toh_RatBloodGlucose_T1092M_20210413_10wk_RBG.raw (F46)
# Unique Identifier
# unknown_679.05463_0.536                                            23.617549
# unknown_641.1087_0.537                                             24.575904
# unknown_951.15973_0.541                                            23.455789
# unknown_329.03067_0.542                                            26.482705
# unknown_969.13147_0.544                                            22.047030
# ...                                                                      ...
# unknown_897.82532_20.148                                           16.927718
# unknown_974.9118_20.163                                            17.646532
# unknown_593.58716_20.175                                           16.687194
# unknown_871.80945_20.196                                           13.966980
# unknown_1003.93829_20.435                                          17.407656
#
# [1029 rows x 60 columns]

# %%
df = np.log2(fr_filt[fr_quant_filenames_in_analytical_order])

fig, axs = plt.subplots(nrows=1, ncols=2, sharey=True, constrained_layout=True)
fig.set_size_inches((10, 8))

for ax, bg_type in zip(axs, ['RBG', 'FBG']):
    for tol_type, position in zip(['normal', 'impaired', 'diabetic'], [1,2,3]):
        # Get filenames that match bg_type and tol_type
        cols = file_grouping[(file_grouping['bg_type'] == bg_type) & \
                             (file_grouping['glucose_tolerance'] == tol_type) & \
                             (file_grouping['quant_file'] == True)]['fr_name']
        ax.boxplot(df[cols].mean(axis=1), positions=[position, ], widths=0.9)
        
        # Option for barplots, much slower to render though
#         ax.bar(position, df[cols].mean(axis=1))
        
    ax.set_title('Random-fed' if bg_type == 'RBG' else 'Fasted', fontsize=15)
    ax.set_xticks([1,2,3], )
    ax.set_xticklabels(['normal', 'impaired', 'diabetic'], fontsize=12)

fig.suptitle('Random-fed vs. fasted feature quant\nby glucose tolerance', fontsize=20)
fig.supxlabel('glucose tolerance', fontsize=15)
fig.supylabel('log2 feature quant', fontsize=15)
# Out:
# Text(0.02, 0.5, 'log2 feature quant')

# %%
bg_dict
# Out:
# {'diabetic': [1076, 1082, 1101],
#  'impaired': [1060, 1062, 1074, 1092, 1102],
#  'normal': [1091, 1093]}

# %%
df = fr_filt

n_rats_per_gluc_tolerance = {'diabetic': 3, 'impaired': 5, 'normal': 2}

# 9 rows for each of 9 lipid classes that have # IDs > 10
# 3 cols for each glucose_tolerance 
fig, axs = plt.subplots(nrows=10, ncols=2, sharey='row', constrained_layout=True)
fig.set_size_inches((8, 35))
# plt.tight_layout()

lipid_classes = df['Lipid Class'].value_counts().iloc[0:10].to_dict()

for i, lipid_class in enumerate(lipid_classes):  # i = row index for axs
    for j, bg_type in enumerate(['RBG', 'FBG']):  # j = column index for axs
        
        # Get the fr_filenames from file_grouping['fr_name'] that match each iterator in each for loop
        # Then get the data from fr[fr_filenames]
        fr_filenames = file_grouping[(file_grouping['quant_file'] == True) & \
#                                      (file_grouping['glucose_tolerance'] == glucose_tolerance) & \
                                     (file_grouping['bg_type'] == bg_type)]['fr_name']
        
        df = fr_filt[fr_filt['Lipid Class'] == lipid_class][fr_filenames]
        norm_df = np.log2(df.filter(regex='1091|1093').mean(axis=1))
        impaired_df = np.log2(df.filter(regex='1060|1062|1074|1092|1102').mean(axis=1))
        diabetic_df = np.log2(df.filter(regex='1076|1082|1101').mean(axis=1))
#         display(norm_df)
#         display(impaired_df)
#         display(diabetic_df)
        
        ax = axs[i][j]
        
        ax.boxplot([norm_df, impaired_df, diabetic_df], widths=0.78)
        ax.grid(alpha=0.5, axis='y')
        ax_title = ('Random-fed' if bg_type == 'RBG' else 'Fasted')
        ax.set_title(f'\n{lipid_class}, n={lipid_classes[lipid_class]}'
                     f'\n{ax_title}')
        ax.set_xticklabels(['normal', 'impaired', 'diabetic'], fontsize=12)
        
fig.suptitle('Lipid Class and Glucose Tolerance\nRandom-fed vs. Fasted\nAverage of all 3 weeks', fontsize=20)
# plt.gcf()
# fig.supylabel('log2 feature quant', fontsize=20)  
    
# plt.savefig(r'..\reports\collaborator reports\preliminary 20210812\figures\lipid class feature quant comparison.png')
# Out:
# Text(0.5, 0.98, 'Lipid Class and Glucose Tolerance\nRandom-fed vs. Fasted\nAverage of all 3 weeks')

# %%
lipid_classes = fr_filt['Lipid Class'].value_counts().iloc[1:11].to_dict()
lipid_classes
# Out:
# {'TG': 105,
#  'PC': 62,
#  'SM': 26,
#  'Plasmanyl-PC': 25,
#  'Plasmenyl-PE': 18,
#  'PI': 14,
#  'LysoPC': 14,
#  'Plasmenyl-PC': 12,
#  'Plasmanyl-PE': 11,
#  'PE': 6}

# %%
df = np.log2(fr_filt[fr_quant_filenames_in_analytical_order])

fig, axs = plt.subplots(nrows=10, ncols=2, sharey=True, sharex=True, constrained_layout=True)
fig.set_size_inches((8, 25))
for i, lipid_class in enumerate(lipid_classes):
    for ax, bg_type in zip(axs, ['RBG', 'FBG']):
        for tol_type, position in zip(['normal', 'impaired', 'diabetic'], [1,2,3]):
            # Get filenames that match bg_type and tol_type
            cols = file_grouping[(file_grouping['bg_type'] == bg_type) & \
                                 (file_grouping['glucose_tolerance'] == tol_type) & \
                                 (file_grouping['quant_file'] == True)]['fr_name']
            ax.boxplot(df[cols].mean(axis=1), positions=[position, ], widths=0.9)

            # Option for barplots, much slower to render though
    #         ax.bar(position, df[cols].mean(axis=1))

        ax.set_title('Random-fed' if bg_type == 'RBG' else 'Fasted', fontsize=15)
        ax.set_xticks([1,2,3], )
        ax.set_xticklabels(['normal', 'impaired', 'diabetic'], fontsize=12)

fig.suptitle('Random-fed vs. fasted feature quant\nby glucose tolerance', fontsize=20)
fig.supxlabel('glucose tolerance', fontsize=15)
fig.supylabel('log2 feature quant', fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-cdad70177041> in <module>
#      10                                  (file_grouping['glucose_tolerance'] == tol_type) & \
#      11                                  (file_grouping['quant_file'] == True)]['fr_name']
# ---> 12             ax.boxplot(df[cols].mean(axis=1), positions=[position, ], widths=0.9)
#      13
#      14             # Option for barplots, much slower to render though
#
# AttributeError: 'numpy.ndarray' object has no attribute 'boxplot'
