# %% [markdown]
# ## This project's custom style sheet is at
# `/data/metadata/Nilerat_matplotlib_stylesheet.mplstyle`

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
mpl.matplotlib_fname()
# Out:
# 'C:\\Users\\bjanderson23\\AppData\\Roaming\\Python\\Python37\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams['pdf.use14corefonts'] = True
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.plot([1, 2, 3, 4])

# %%
plt.style.use('../data/metadata/Nilerat_matplotlib_stylesheet.mplstyle')

# %%
with plt.style.context('../data/metadata/Nilerat_matplotlib_stylesheet.mplstyle'):
    plt.plot([1, 2, 3, 4])

# %%
plt.rcParams['axes.']
